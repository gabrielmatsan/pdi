# %%
import cv2 # opencv no colab
from google.colab.patches import cv2_imshow #function imshow() para colab

# %%
img = cv2.imread('mario.jpg')

cv2_imshow(img)
img
cv2_imshow(img/2)
cv2_imshow(img*2)

cv2_imshow(img**100)
cv2_imshow(img+255)
cv2_imshow(img//100)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400>
# <PIL.Image.Image image mode=RGB size=400x400>
# <PIL.Image.Image image mode=RGB size=400x400>
# <PIL.Image.Image image mode=RGB size=400x400>
# <PIL.Image.Image image mode=RGB size=400x400>
# <PIL.Image.Image image mode=RGB size=400x400>

# %%
print(img)
# Out:
# [[[173  96   0]
#   [173  96   0]
#   [173  96   0]
#   ...
#   [173  96   0]
#   [173  96   0]
#   [173  96   0]]
#
#  [[173  96   0]
#   [173  96   0]
#   [173  96   0]
#   ...
#   [173  96   0]
#   [173  96   0]
#   [173  96   0]]
#
#  [[173  96   0]
#   [173  96   0]
#   [173  96   0]
#   ...
#   [173  96   0]
#   [173  96   0]
#   [173  96   0]]
#
#  ...
#
#  [[173  96   0]
#   [173  96   0]
#   [173  96   0]
#   ...
#   [173  96   0]
#   [173  96   0]
#   [173  96   0]]
#
#  [[173  96   0]
#   [173  96   0]
#   [173  96   0]
#   ...
#   [173  96   0]
#   [173  96   0]
#   [173  96   0]]
#
#  [[173  96   0]
#   [173  96   0]
#   [173  96   0]
#   ...
#   [173  96   0]
#   [173  96   0]
#   [173  96   0]]]

# %%
B, G, R = cv2.split(img)
cv2_imshow(B)
cv2_imshow(G)
cv2_imshow(R)
# Out:
# <PIL.Image.Image image mode=L size=400x400>
# <PIL.Image.Image image mode=L size=400x400>
# <PIL.Image.Image image mode=L size=400x400>
